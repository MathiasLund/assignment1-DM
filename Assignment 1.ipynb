# %% [markdown]
# # A

# %%
import pandas as pd

# %%
df = pd.read_csv('MobilePrice.csv')

# %% [markdown]
# 1:

# %%
print(f'Number of rows: {df.shape[0]}')
print(f'Number of columns: {df.shape[1]}')
# Out:
# Number of rows: 2000
# Number of columns: 21

# %% [markdown]
# 2:

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# There are no missing values in any of the columns.

# %% [markdown]
# 3:

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df.clock_speed)
# Out:
# (array([551., 116., 168., 138., 203., 127., 202., 136., 184., 175.]),
#  array([0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# 4:

# %%
colors = ("red","green")
area = 3.14*3
plt.scatter(df.px_height, df.px_width, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot Mobile Prices')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
